# %% [markdown]
# ## Notebook Content Overview
#
# This notebook will guide you through various Natural Language Processing (NLP) techniques, focusing on text preprocessing and advanced analysis. The topics covered include:
# *   **NLTK**
# *   **Text Preprocessing for NLP**
# *   **Tokenization**
# *   **Stop Words Removal Function**
# *   **Stemming Function**
# *   **Lemmatization Function**
# *   **Part-of-Speech Tagging**
# *   **Sentiment Analysis**
# *   **spaCy for Advanced NLP**
# *   **Named Entity Recognition (NER)**
# *   **Dependency Parsing**
# *   **Text Similarity**

# %% [markdown]
# **NLTK (Natural Language Toolkit)** is one of the oldest and most popular Python libraries for working with human language text (Natural Language Processing — NLP).
#
# It is mainly used for:
#
# * Learning NLP concepts
# * Text preprocessing
# * Classical NLP tasks
# * Research and education

# %%
# !pip install nltk

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tag import pos_tag
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
sample_text = """
Artificial Intelligence is transforming industries across the world by enabling
machines to perform tasks that normally require human intelligence. Machine learning,
deep learning, and data analysis are some of the most important areas within AI.
Today, AI is used in healthcare, finance, education, cybersecurity, and many other fields.
Researchers continue to develop smarter systems that can learn, reason, and assist humans
in solving complex problems efficiently.
"""

# %% [markdown]
# **1. Tokenization Function**

# %%
words = word_tokenize(sample_text)
print("---------Words Tokenize-------------- ")
print(words)

senetance = sent_tokenize(sample_text)
print("---------Senetance Tokenize-------------- ")
print(senetance)
# Out:
# ---------Words Tokenize--------------
# ['Artificial', 'Intelligence', 'is', 'transforming', 'industries', 'across', 'the', 'world', 'by', 'enabling', 'machines', 'to', 'perform', 'tasks', 'that', 'normally', 'require', 'human', 'intelligence', '.', 'Machine', 'learning', ',', 'deep', 'learning', ',', 'and', 'data', 'analysis', 'are', 'some', 'of', 'the', 'most', 'important', 'areas', 'within', 'AI', '.', 'Today', ',', 'AI', 'is', 'used', 'in', 'healthcare', ',', 'finance', ',', 'education', ',', 'cybersecurity', ',', 'and', 'many', 'other', 'fields', '.', 'Researchers', 'continue', 'to', 'develop', 'smarter', 'systems', 'that', 'can', 'learn', ',', 'reason', ',', 'and', 'assist', 'humans', 'in', 'solving', 'complex', 'problems', 'efficiently', '.']
# ---------Senetance Tokenize--------------
# ...

# %% [markdown]
# **3. Stop Words Removal Function** remove words that dosenot have meaningful information like ( is , it , ect ... )
#
# Used to :
#
#
# *   remove noise
# *   decrease vocablary size
# *   mprove model efficiency and focus on important words

# %%
# import nltk
# nltk.download('stopwords')
# ar_stop_words = set(stopwords.words('arabic'))

# print(ar_stop_words)

# %%
import nltk
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
filtered_words = [word.lower() for word in words if word.lower() not in stop_words and word.isalpha()]
print(f"Original words: {len(words)}")
print(f"After removing stop words: {len(filtered_words)}")
print(f"Filtered words: {filtered_words}")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Original words: 79
# After removing stop words: 46
# Filtered words: ['artificial', 'intelligence', 'transforming', 'industries', 'across', 'world', 'enabling', 'machines', 'perform', 'tasks', 'normally', 'require', 'human', 'intelligence', 'machine', 'learning', 'deep', 'learning', 'data', 'analysis', 'important', 'areas', 'within', 'ai', 'today', 'ai', 'used', 'healthcare', 'finance', 'education', 'cybersecurity', 'many', 'fields', 'researchers', 'continue', 'develop', 'smarter', 'systems', 'learn', 'reason', 'assist', 'humans', 'solving', 'complex', 'problems', 'efficiently']

# %% [markdown]
# **4. Stemming Function**
# Stemming is the process of reducing words to their base or root form by removing suffixes and prefixes. The resulting stem may not always be a valid word but represents a group of related words.
#
# Example:
# * "running", "runner", "runs" → "run"
#
# Why is Stemming Useful?
#
# * Reduces different forms of a word to a common base
# * Helps in grouping words with similar meaning
# * Decreases vocabulary size and improves generalization

# %%
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_words]
print(stemmed_words)
# Out:
# ['artifici', 'intellig', 'transform', 'industri', 'across', 'world', 'enabl', 'machin', 'perform', 'task', 'normal', 'requir', 'human', 'intellig', 'machin', 'learn', 'deep', 'learn', 'data', 'analysi', 'import', 'area', 'within', 'ai', 'today', 'ai', 'use', 'healthcar', 'financ', 'educ', 'cybersecur', 'mani', 'field', 'research', 'continu', 'develop', 'smarter', 'system', 'learn', 'reason', 'assist', 'human', 'solv', 'complex', 'problem', 'effici']

# %% [markdown]
# **5. Lemmatization**
# reduces a word to its dictionary base form (called a lemma).
#
# It understands:
#
# * grammar
# * part of speech
# * actual language meaning

# %%
import nltk
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
print(lemmatized_words)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ['Artificial', 'Intelligence', 'is', 'transforming', 'industry', 'across', 'the', 'world', 'by', 'enabling', 'machine', 'to', 'perform', 'task', 'that', 'normally', 'require', 'human', 'intelligence', '.', 'Machine', 'learning', ',', 'deep', 'learning', ',', 'and', 'data', 'analysis', 'are', 'some', 'of', 'the', 'most', 'important', 'area', 'within', 'AI', '.', 'Today', ',', 'AI', 'is', 'used', 'in', 'healthcare', ',', 'finance', ',', 'education', ',', 'cybersecurity', ',', 'and', 'many', 'other', 'field', '.', 'Researchers', 'continue', 'to', 'develop', 'smarter', 'system', 'that', 'can', 'learn', ',', 'reason', ',', 'and', 'assist', 'human', 'in', 'solving', 'complex', 'problem', 'efficiently', '.']

# %% [markdown]
# **6.Part-of-Speech Tagging (POS Tagging)**
#  is a technique in Natural Language Processing where each word in a sentence is labeled with its grammatical role.
#
#
# ** Why POS Tagging Matters**
#  Computers normally see text as just tokens.
#
# POS tagging adds grammatical understanding.

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
pos_tags = pos_tag(words)
print(pos_tags)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# ...

# %% [markdown]
# **7.Sentiment Analysis**
# Sentiment Analysis is the process of identifying and categorizing emotions or opinions expressed in a piece of text—typically as positive, negative, or neutral.
#
# In NLTK, we can perform sentiment analysis using the built-in VADER sentiment analyzer, which is particularly effective for short texts like social media posts.

# %%
import nltk
nltk.download('vader_lexicon')

def nltk_sentiment_analysis(text):
    """Analyze sentiment of text"""
    print("=== SENTIMENT ANALYSIS ===")
    sia = SentimentIntensityAnalyzer()
    sentiment_scores = sia.polarity_scores(text)

    print(f"Sentiment scores: {sentiment_scores}")

    # Interpret the scores
    if sentiment_scores['compound'] >= 0.05:
        print("Overall sentiment: Positive")
    elif sentiment_scores['compound'] <= -0.05:
        print("Overall sentiment: Negative")
    else:
        print("Overall sentiment: Neutral")

    return sentiment_scores

# Run the function
sentiment_scores = nltk_sentiment_analysis(sample_text)
# Out:
# === SENTIMENT ANALYSIS ===
# Sentiment scores: {'neg': 0.035, 'neu': 0.756, 'pos': 0.21, 'compound': 0.9134}
# Overall sentiment: Positive
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
neg_text = "I do not like the movie ,I only like the end of the movie it was great, but overall it was boring"
ss = nltk_sentiment_analysis(neg_text)
# Out:
# === SENTIMENT ANALYSIS ===
# Sentiment scores: {'neg': 0.237, 'neu': 0.664, 'pos': 0.1, 'compound': -0.3632}
# Overall sentiment: Negative

# %% [markdown]
# **8-spaCy**
# * spaCy is an industrial-strength Natural Language Processing (NLP) library built for production-level applications. It is known for being fast, efficient, and accurate, with easy integration into real-world systems.

# %% [markdown]
# ⭐ Key Features of spaCy:
# * ⚡ High Performance: Optimized for speed and large-scale processing.
# *🌐 Pre-trained Models: Supports multiple languages (English, Arabic, German, etc.).
# * 🧠 Deep Learning Ready: Seamless integration with deep learning frameworks (e.g., PyTorch, TensorFlow).
# * 🏗️ Production Focused: Designed for real-world use, not just research or prototyping.
# * 🔗 Advanced NLP Tasks:
# Tokenization
# Part-of-Speech Tagging (POS)
# Dependency Parsing
# Named Entity Recognition (NER)
# Text Classification

# %%
# !pip install spacy

# %%
import spacy
from spacy import displacy #Help with visualize NLP results,
# Load the English model
nlp = spacy.load("en_core_web_sm")
# Process the text
doc = nlp(sample_text) # Convert it into Doc object (Strucured Object contains Tokens , POS tags , entities , lemma etc .... )

# %% [markdown]
# **10. Named Entity Recognition (NER)**
# *  What is Named Entity Recognition (NER)?
# Named Entity Recognition (NER) is a key task in Natural Language Processing
#
# (NLP) where the goal is to automatically detect and classify named entities in text into predefined categories such as:
#
# * Persons
# * Organizations
# * Locations
# * Dates
# * Monetary values
# And more...

# %%
import spacy


nlp = spacy.load("en_core_web_sm")

doc = nlp("I am Mohammed , I work at SADAIA")



for ent in doc.ents:
    print(ent.text, ent.label_ )
# Out:
# Mohammed PERSON
# SADAIA ORG

# %%
import spacy

# Load the spaCy English model once
nlp = spacy.load("en_core_web_sm")

def detailed_ner_analysis(text):
    """
    Perform Named Entity Recognition (NER) on the given text using spaCy.
    Displays entities with their labels and explanations, along with token details.
    """
    doc = nlp(text)

    print("\n=== NAMED ENTITY RECOGNITION (NER) ===")
    print(f"📄 Text length: {len(text)} characters")
    print(f"🔢 Number of tokens: {len(doc)}")
    print(f"🔍 Number of entities: {len(doc.ents)}\n")

    if doc.ents:
        print("🗂 Entities Found:")
        for ent in doc.ents:
            label_desc = spacy.explain(ent.label_) or "No description available"
            print(f"- {ent.text}  ➔  {ent.label_} ({label_desc})")
    else:
        print("No entities detected in the text.")

    print("\n🔠 First 10 Tokens (with POS and Entity Type):")
    for token in doc[:10]:
        ent_type = token.ent_type_ if token.ent_type_ else "None"
        print(f"{token.text:<15} | {token.pos_:<10} | {ent_type}")

    return doc.ents



# Run the analysis
entities = detailed_ner_analysis(sample_text)
# Out:
# === NAMED ENTITY RECOGNITION (NER) ===
# 📄 Text length: 470 characters
# 🔢 Number of tokens: 86
# 🔍 Number of entities: 4
#
# 🗂 Entities Found:
# - Artificial Intelligence  ➔  PERSON (People, including fictional)
# - AI  ➔  GPE (Countries, cities, states)
# - Today  ➔  DATE (Absolute or relative dates or periods)
# - AI  ➔  GPE (Countries, cities, states)
#
# 🔠 First 10 Tokens (with POS and Entity Type):
#
#                | SPACE      | None
# Artificial      | PROPN      | PERSON
# Intelligence    | PROPN      | PERSON
# is              | AUX        | None
# transforming    | VERB       | None
# industries      | NOUN       | None
# across          | ADP        | None
# the             | DET        | None
# world           | NOUN       | None
# by              | ADP        | None

# %% [markdown]
# ## 11. Dependency Parsing (in simple terms)
#
# Dependency Parsing is a way for NLP systems (like spaCy) to understand how words in a sentence are connected grammatically.
#
# Instead of just looking at words one by one, it builds a tree structure showing:
#
# *   Which word depends on which word
# *   What type of relationship they have
#
# **Example:** In the sentence "Apple acquired X Company," dependency parsing would identify "acquired" as the main verb, "Apple" as the subject (nsubj) depending on "acquired," and "X Company" as the direct object (dobj) also depending on "acquired."

# %%
import spacy
from spacy import displacy

nlp = spacy.load("en_core_web_sm")

def visualize_dependencies(text):
    doc = nlp(text)
    print(f"\n--- Dependency Relations for: '{text}' ---")
    for token in doc:
        print(f"{token.text:<15} {token.dep_:<10} {token.head.text:<15} {token.pos_:<10}")

    # Visualize the dependency tree
    displacy.render(doc, style="dep", jupyter=True, options={'distance': 90})

# Example 1: Simple sentence
visualize_dependencies("Apple acquired X Company.")

# Example 2: From our sample text
visualize_dependencies("Artificial Intelligence is transforming industries.")

# Example 3: A more complex sentence from the sample_text
sentence_for_parsing = "Researchers continue to develop smarter systems that can learn, reason, and assist humans in solving complex problems efficiently."
visualize_dependencies(sentence_for_parsing)
# Out:
# --- Dependency Relations for: 'Apple acquired X Company.' ---
# Apple           nsubj      acquired        PROPN
# acquired        ROOT       acquired        VERB
# X               compound   Company         PROPN
# Company         dobj       acquired        PROPN
# .               punct      acquired        PUNCT
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0f4feebda4394eb0a95ef1ddf87a0831-0" class="displacy" width="410" height="227.0" direction="ltr" style="max-width: none; height: 227.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
# ...

# %% [markdown]
# ** 12.  Text Similarity**

# %%
doc1 = nlp("I like dogs")
doc2 = nlp('I like cats')

doc3 = nlp("I work as a Developer")
doc4 = nlp("I always wake up earlu")


simlarity = doc1.similarity(doc2)
print(f"Similarity between doc1 and doc2: {simlarity}")

simlarity = doc1.similarity(doc3)
print(f"Similarity between doc1 and doc3: {simlarity}")
# Out:
# Similarity between doc1 and doc2: 0.9271236062049866
# Similarity between doc1 and doc3: 0.3105560541152954
# /tmp/ipykernel_598/3445843934.py:8: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   simlarity = doc1.similarity(doc2)
# ...
